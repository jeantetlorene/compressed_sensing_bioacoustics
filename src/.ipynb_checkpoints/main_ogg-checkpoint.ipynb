# %% [markdown]
# # OGG Audio Compression for Bioacoustic Classifier Systems

# %%
# Step 1: Import the necessary class from compress.py
from compress import OggCompression  # Import the OggCompression class

# Step 2: Create an instance of the OggCompression class with the input WAV file
input_wav = "../data/hainan_gibbon/audio/HGSM3C_0+1_20150810_052200.wav"

# Instantiate the OggCompression class
ogg_compression = OggCompression(input_wav)

# Step 3: Compress the WAV file and save it as an OGG file
#output_ogg = "../data/hainan_gibbon/audio/HGSM3C_0+1_20150810_052200.ogg"
#ogg_compression.compress(output_ogg)

# Step 4 (Optional): If you want to keep the OGG data in memory, you can skip the saving part
# and just return the OGG data (though the process might be complex in-memory for OGG).
wav_data, wav_sample_rate = ogg_compression.compress()

# Example: If you want to check the WAV data you got after compression
print(f"Length of WAV data (in memory): {len(wav_data)} samples")
# Out:
# Length of WAV data (in memory): 30812586 samples
